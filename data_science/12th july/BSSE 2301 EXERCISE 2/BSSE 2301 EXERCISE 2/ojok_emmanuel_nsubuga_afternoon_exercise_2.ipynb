# %% [markdown]
# # OJOK EMMANUEL NSUBUGA
#
# - Registration number: 21/U/06816/PS
# - Student number: 2100706816
#
# ### DATA ANALYSIS WITH PANDAS (EXERCISE SET 2)

# %% [markdown]
# #### SERIES

# %% [markdown]
# Import libraries

# %%
# import pandas
import pandas as pd

# %% [markdown]
# Question 1

# %%
# Create the sample series
series1 = pd.Series([4, 65, 436, 3, 9])
series2 = pd.Series([7, 0, 3, 897, 9])

# Compare the elements of the two series
comparison_result = series1 == series2

# Display the comparison result
print(comparison_result)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# Question 2

# %%
# Create the sample series
series1 = pd.Series([2, 4, 6, 8, 14])
series2 = pd.Series([1, 3, 5, 7, 9])

# Addition
addition_result = series1 + series2
print("Addition:")
print(addition_result)

# Subtraction
subtraction_result = series1 - series2
print("\nSubtraction:")
print(subtraction_result)

# Multiplication
multiplication_result = series1 * series2
print("\nMultiplication:")
print(multiplication_result)

# Division
division_result = series1 / series2
print("\nDivision:")
print(division_result)
# Out:
# Addition:
# 0     3
# 1     7
# 2    11
# 3    15
# 4    23
# dtype: int64
#
# Subtraction:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    5
# dtype: int64
#
# Multiplication:
# 0      2
# 1     12
# 2     30
# 3     56
# 4    126
# dtype: int64
#
# Division:
# 0    2.000000
# 1    1.333333
# 2    1.200000
# 3    1.142857
# 4    1.555556
# dtype: float64

# %% [markdown]
# Question 3

# %%
# Sample dictionary
dictionary1 = {'Josh': 24, 'Sam': 36, 'Peace': 19, 'Charles': 65, 'Tom': 44}

# Convert dictionary to series
series1 = pd.Series(dictionary1)

# Display the resulting series
print(series1)
# Out:
# Josh       24
# Sam        36
# Peace      19
# Charles    65
# Tom        44
# dtype: int64

# %% [markdown]
# Question 4

# %%
# we have to import numpy
import numpy as np

# Sample series
series1 = pd.Series(['Love', 800, 'Joy', 789.9, 'Peace', True])

# Convert series to array
array1 = np.array(series1)

# Display the resulting array
print(array1)
# Out:
# ['Love' 800 'Joy' 789.9 'Peace' True]

# %% [markdown]
# Question 5

# %%
# load the dataset
df = pd.read_csv("AfricaCupofNationsMatches.csv")

# %%
# Get the most frequent value
most_frequent_value = df['HomeTeamGoals'].mode().values[0]
print(most_frequent_value)

# Replace everything else as 'Other'
df['HomeTeamGoals'] = df['HomeTeamGoals'].where(df['HomeTeamGoals'] == most_frequent_value, 'Other')

# Display the modified series
print(df['HomeTeamGoals'])
# Out:
# 1.0
# 0        1.0
# 1      Other
# 2      Other
# 3      Other
# 4        1.0
#        ...
# 617    Other
# 618      1.0
# 619    Other
# 620    Other
# 621    Other
# Name: HomeTeamGoals, Length: 622, dtype: object

# %% [markdown]
# #### DATAFRAMES

# %% [markdown]
# Question 1

# %%
# load the dataset
df = pd.read_csv("AfricaCupofNationsMatches.csv")

# %% [markdown]
# Question 2

# %%
# Get the first 7 rows
first_7_rows = df.head(7)

# Display the result
first_7_rows
# Out:
#    Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0  1957  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1  1957  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2  1957  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3  1959  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4  1959  25-May-59   NaN     Sudan        Ethiopia            1.0
# 5  1959  29-May-59   NaN      Egypt          Sudan            2.0
# 6  1962  14-Jan-62   NaN  Ethiopia         Tunisia            4.0
#
#    AwayTeamGoals             Stage  \
# 0            2.0        Semifinals
# 1            NaN        Semifinals
# 2            0.0             Final
# 3            0.0  Final Tournament
# 4            0.0  Final Tournament
# 5            1.0  Final Tournament
# 6            2.0        Semifinals
#
#                                 SpecialWinConditions                 Stadium  \
# ...

# %% [markdown]
# Question 3

# %%
# Select the desired columns
selected_columns = df[['HomeTeam', 'AwayTeam', 'HomeTeamGoals', 'AwayTeamGoals']]

# Display the selected columns
selected_columns
# Out:
#         HomeTeam       AwayTeam  HomeTeamGoals  AwayTeamGoals
# 0         Sudan           Egypt            1.0            2.0
# 1      Ethiopia    South Africa            NaN            NaN
# 2         Egypt        Ethiopia            4.0            0.0
# 3          Egypt       Ethiopia            4.0            0.0
# 4         Sudan        Ethiopia            1.0            0.0
# ..           ...            ...            ...            ...
# 617  Madagascar         Tunisia            0.0            3.0
# 618     Senegal         Tunisia            1.0            0.0
# 619     Algeria         Nigeria            2.0            1.0
# 620     Tunisia         Nigeria            0.0            1.0
# 621     Senegal         Algeria            0.0            1.0
#
# [622 rows x 4 columns]

# %% [markdown]
# Question 4

# %%
# Select the rows where 'Egypt' appears in any column
selected_rows = df[df.applymap(lambda x: 'Egypt' in str(x)).any(axis=1)]

# Display the selected rows
selected_rows
# Out:
#      Year                         Date   Time  HomeTeam       AwayTeam  \
# 0    1957                     10-Feb-57    NaN   Sudan           Egypt
# 2    1957                     16-Feb-57    NaN   Egypt        Ethiopia
# 3    1959                     22-May-59    NaN    Egypt       Ethiopia
# 5    1959                     29-May-59    NaN    Egypt          Sudan
# 7    1962                     18-Jan-62    NaN    Egypt         Uganda
# ..    ...                           ...    ...      ...            ...
# 569  2017  5 February 2017 (2017-02-05)  20:00   Egypt        Cameroon
# 570  2019     21 June 2019 (2019-06-21)  22:00   Egypt        Zimbabwe
# 573  2019     26 June 2019 (2019-06-26)  22:00   Egypt        DR Congo
# 574  2019     30 June 2019 (2019-06-30)  21:00  Uganda           Egypt
# 609  2019      6 July 2019 (2019-07-06)  21:00   Egypt    South Africa
#
#      HomeTeamGoals  AwayTeamGoals             Stage SpecialWinConditions  \
# ...

# %% [markdown]
# Question 5

# %%
# Count the number of rows and columns
num_rows = df.shape[0]
num_columns = df.shape[1]

# Display the counts
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 622
# Number of columns: 12

# %% [markdown]
# Question 6

# %%
# Select the rows where 'Attendance' is missing
selected_rows = df[df['Attendance'].isnull()]

# Display the selected rows
selected_rows
# Out:
#      Year                         Date   Time        HomeTeam       AwayTeam  \
# 1    1957                     10-Feb-57    NaN      Ethiopia    South Africa
# 8    1962                     20-Jan-62    NaN       Tunisia          Uganda
# 9    1962                     21-Jan-62    NaN      Ethiopia           Egypt
# 10   1963                     24-Nov-63    NaN         Ghana         Tunisia
# 11   1963                     26-Nov-63    NaN         Ghana        Ethiopia
# ..    ...                           ...    ...            ...            ...
# 565  2017  29 January 2017 (2017-01-29)  20:00         Egypt         Morocco
# 566  2017  1 February 2017 (2017-02-01)  20:00  Burkina Faso           Egypt
# 567  2017  2 February 2017 (2017-02-02)  20:00      Cameroon           Ghana
# 568  2017  4 February 2017 (2017-02-04)  20:00  Burkina Faso           Ghana
# 569  2017  5 February 2017 (2017-02-05)  20:00         Egypt        Cameroon
#
# ...

# %% [markdown]
# Question 7

# %%
# Select the rows where 'HomeTeamGoals' are between 3 and 6 (inclusive)
selected_rows = df[(df['HomeTeamGoals'] >= 3) & (df['HomeTeamGoals'] <= 6)]

# Display the selected rows
selected_rows
# Out:
#      Year                         Date   Time    HomeTeam     AwayTeam  \
# 2    1957                     16-Feb-57    NaN     Egypt      Ethiopia
# 3    1959                     22-May-59    NaN      Egypt     Ethiopia
# 6    1962                     14-Jan-62    NaN  Ethiopia       Tunisia
# 8    1962                     20-Jan-62    NaN   Tunisia        Uganda
# 9    1962                     21-Jan-62    NaN  Ethiopia         Egypt
# ..    ...                           ...    ...        ...          ...
# 553  2017  20 January 2017 (2017-01-20)  20:00   Morocco          Togo
# 585  2019     27 June 2019 (2019-06-27)  22:00     Kenya      Tanzania
# 595  2019     24 June 2019 (2019-06-24)  22:00      Mali    Mauritania
# 608  2019      6 July 2019 (2019-07-06)  18:00   Nigeria      Cameroon
# 611  2019      7 July 2019 (2019-07-07)  21:00   Algeria        Guinea
#
#      HomeTeamGoals  AwayTeamGoals              Stage    SpecialWinConditions  \
# ...

# %% [markdown]
# Question 8

# %%
# Change the value of "AwayTeamGoals" in the 3rd row to 10
df.at[2, 'AwayTeamGoals'] = 10

# Display the modified DataFrame
df
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %% [markdown]
# Question 9

# %%
# Sort the DataFrame by 'HomeTeam' in ascending order, then by 'HomeTeamScores' in descending order
# HomeTeamScores column is not in the dataset so I will use HomeTeamGoals instead
sorted_df = df.sort_values(['HomeTeam', 'HomeTeamGoals'], ascending=[True, False])

# Display the sorted DataFrame
sorted_df
# Out:
#      Year                         Date           Time    HomeTeam  \
# 205  1990                      2-Mar-90            NaN   Algeria
# 29   1968                     14-Jan-68            NaN   Algeria
# 135  1980                     16-Mar-80            NaN   Algeria
# 164  1984                      5-Mar-84            NaN   Algeria
# 171  1984                     17-Mar-84            NaN   Algeria
# ..    ...                           ...            ...        ...
# 521  2012                     12-Feb-12  20:30[note 1]    Zambia
# 549  2017  23 January 2017 (2017-01-23)          20:00  Zimbabwe
# 398  2004                     25-Jan-04          16:30  Zimbabwe
# 437  2006                     23-Jan-06          20:00  Zimbabwe
# 575  2019     30 June 2019 (2019-06-30)          21:00  Zimbabwe
#
#          AwayTeam  HomeTeamGoals  AwayTeamGoals              Stage  \
# 205       Nigeria            5.0            1.0            Group A
# ...

# %% [markdown]
# Question 10

# %%
# Get the list of column headers
column_headers = df.columns.tolist()

# Display the list of column headers
column_headers
# Out:
# ['Year',
#  'Date ',
#  'Time ',
#  'HomeTeam',
#  'AwayTeam',
#  'HomeTeamGoals',
#  'AwayTeamGoals',
#  'Stage',
#  'SpecialWinConditions',
#  'Stadium',
#  'City',
#  'Attendance']

# %% [markdown]
# Question 11

# %%
# Create a new column with the desired data
new_column_data = [10] * len(df)  # Example data to fill the new column
column_name = 'MyRandomColumn'  # Name of the new column

# Append the new column to the DataFrame
df[column_name] = new_column_data

# Display the modified DataFrame
df
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %% [markdown]
# Question 12

# %%
# Create two rows with NaN values
new_rows = [{"Year":2020,"Date":"July-10-2020","Time":"22:00","HomeTeam":"Uganda","AwayTeam":"Senegal",
             "HomeTeamGoals":4,"AwayTeamGoals":1,"Stage":"Final","SpecialWinConditions":np.nan,
             "Stadium":"Stade International du Caire","City":"Cairo","Attendance":40000,"MyRandomColumn":10},
             {"Year":2021,"Date":"June-13-2020","Time":"21:00","HomeTeam":"Senegal","AwayTeam":"Kenya",
             "HomeTeamGoals":3,"AwayTeamGoals":2,"Stage":"Final","SpecialWinConditions":np.nan,
             "Stadium":"Namboole Stadium","City":"Kampala","Attendance":32000,"MyRandomColumn":10}
             ]

# Add the new rows to the DataFrame
for row in new_rows:
    df.loc[len(df)] = row

# Display the modified DataFrame
df
# Out:
#      Year                      Date   Time    HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN     Sudan           Egypt
# 1    1957                  10-Feb-57    NaN  Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN     Egypt        Ethiopia
# 3    1959                  22-May-59    NaN      Egypt       Ethiopia
# 4    1959                  25-May-59    NaN     Sudan        Ethiopia
# ..    ...                        ...    ...        ...            ...
# 619  2019  14 July 2019 (2019-07-14)  21:00   Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00   Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00   Senegal         Algeria
# 622  2020                        NaN    NaN     Uganda        Senegal
# 623  2021                        NaN    NaN    Senegal          Kenya
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 0              1.0            2.0            Semifinals
# ...

# %% [markdown]
# Question 13

# %%
# Change 'Uganda' to 'China' in the 'AwayTeam' column
df['AwayTeam'] = df['AwayTeam'].replace('Uganda', 'China')

# Display the modified DataFrame
df
# Out:
#      Year                      Date   Time    HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN     Sudan           Egypt
# 1    1957                  10-Feb-57    NaN  Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN     Egypt        Ethiopia
# 3    1959                  22-May-59    NaN      Egypt       Ethiopia
# 4    1959                  25-May-59    NaN     Sudan        Ethiopia
# ..    ...                        ...    ...        ...            ...
# 619  2019  14 July 2019 (2019-07-14)  21:00   Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00   Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00   Senegal         Algeria
# 622  2020                        NaN    NaN     Uganda        Senegal
# 623  2021                        NaN    NaN    Senegal          Kenya
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 0              1.0            2.0            Semifinals
# ...

# %% [markdown]
# Question 14

# %%
# Reset the index of the DataFrame
df.reset_index(drop=True, inplace=True)

# Display the modified DataFrame
df
# Out:
#      Year                      Date   Time    HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN     Sudan           Egypt
# 1    1957                  10-Feb-57    NaN  Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN     Egypt        Ethiopia
# 3    1959                  22-May-59    NaN      Egypt       Ethiopia
# 4    1959                  25-May-59    NaN     Sudan        Ethiopia
# ..    ...                        ...    ...        ...            ...
# 619  2019  14 July 2019 (2019-07-14)  21:00   Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00   Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00   Senegal         Algeria
# 622  2020                        NaN    NaN     Uganda        Senegal
# 623  2021                        NaN    NaN    Senegal          Kenya
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 0              1.0            2.0            Semifinals
# ...

# %% [markdown]
# Question 15

# %%
# Check if 'Stadium' column is present in the DataFrame
if 'Stadium' in df.columns:
    print("The 'Stadium' column is present in the DataFrame.")
else:
    print("The 'Stadium' column is not present in the DataFrame.")
# Out:
# The 'Stadium' column is present in the DataFrame.

# %% [markdown]
# Question 16

# %%
# data types of the columns before
df.dtypes

# Convert the data type of 'AwayTeamGoals' to float
df['AwayTeamGoals'] = df['AwayTeamGoals'].astype(float)

# Display the modified DataFrame
df.dtypes
# Out:
# Year                      int64
# Date                     object
# Time                     object
# HomeTeam                 object
# AwayTeam                 object
# HomeTeamGoals           float64
# AwayTeamGoals           float64
# Stage                    object
# SpecialWinConditions     object
# Stadium                  object
# City                     object
# Attendance              float64
# MyRandomColumn            int64
# dtype: object

# %% [markdown]
# Question 17

# %%
# Remove the last 10 rows from the DataFrame
df = df.iloc[:-10]

# Display the modified DataFrame
df
# Out:
#      Year                     Date   Time      HomeTeam       AwayTeam  \
# 0    1957                 10-Feb-57    NaN       Sudan           Egypt
# 1    1957                 10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                 16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                 22-May-59    NaN        Egypt       Ethiopia
# 4    1959                 25-May-59    NaN       Sudan        Ethiopia
# ..    ...                       ...    ...          ...            ...
# 609  2019  6 July 2019 (2019-07-06)  21:00       Egypt    South Africa
# 610  2019  7 July 2019 (2019-07-07)  18:00  Madagascar        DR Congo
# 611  2019  7 July 2019 (2019-07-07)  21:00     Algeria          Guinea
# 612  2019  8 July 2019 (2019-07-08)  18:00        Mali     Ivory Coast
# 613  2019  8 July 2019 (2019-07-08)  21:00       Ghana         Tunisia
#
#      HomeTeamGoals  AwayTeamGoals             Stage  \
# 0              1.0            2.0        Semifinals
# ...

# %% [markdown]
# Question 18

# %%
# Iterate over rows in the DataFrame
for index, row in df.iterrows():
    # Access row data using row[column_name]
    print("Row index:", index)
    print("HomeTeam:", row['HomeTeam'])
    print("AwayTeam:", row['AwayTeam'])
    print("HomeTeamGoals:", row['HomeTeamGoals'])
    print("AwayTeamGoals:", row['AwayTeamGoals'])
    print("-------------------")

# %% [markdown]
# Question 19

# %%
# Define the desired column order
new_column_order = ['AwayTeam', 'HomeTeam', 'AwayTeamGoals', 'HomeTeamGoals',
                     'Year','Stage','MyRandomColumn', 'SpecialWinConditions',
                       'Stadium', 'City', 'Attendance']

# Reorder the columns based on the new order
df = df[new_column_order]

# Display the modified DataFrame
df
# Out:
#           AwayTeam     HomeTeam  AwayTeamGoals  HomeTeamGoals  Year  \
# 0            Egypt       Sudan             2.0            1.0  1957
# 1     South Africa    Ethiopia             NaN            NaN  1957
# 2         Ethiopia       Egypt            10.0            4.0  1957
# 3         Ethiopia        Egypt            0.0            4.0  1959
# 4         Ethiopia       Sudan             0.0            1.0  1959
# ..             ...          ...            ...            ...   ...
# 609   South Africa       Egypt             1.0            0.0  2019
# 610       DR Congo  Madagascar             2.0            2.0  2019
# 611         Guinea     Algeria             0.0            3.0  2019
# 612    Ivory Coast        Mali             1.0            0.0  2019
# 613        Tunisia       Ghana             1.0            1.0  2019
#
#                 Stage  MyRandomColumn  \
# 0          Semifinals              10
# 1          Semifinals              10
# ...

# %% [markdown]
# Question 20

# %%
# Filter the DataFrame to keep only rows where 'HomeTeamGoals' is not equal to 0
df = df[df['HomeTeamGoals'] != 0]

# Reset the index of the modified DataFrame
df.reset_index(drop=True, inplace=True)

# Display the modified DataFrame
df
# Out:
#           AwayTeam     HomeTeam  AwayTeamGoals  HomeTeamGoals  Year  \
# 0            Egypt       Sudan             2.0            1.0  1957
# 1     South Africa    Ethiopia             NaN            NaN  1957
# 2         Ethiopia       Egypt            10.0            4.0  1957
# 3         Ethiopia        Egypt            0.0            4.0  1959
# 4         Ethiopia       Sudan             0.0            1.0  1959
# ..             ...          ...            ...            ...   ...
# 484          Benin     Morocco             1.0            1.0  2019
# 485       Cameroon     Nigeria             2.0            3.0  2019
# 486       DR Congo  Madagascar             2.0            2.0  2019
# 487         Guinea     Algeria             0.0            3.0  2019
# 488        Tunisia       Ghana             1.0            1.0  2019
#
#                 Stage  MyRandomColumn  \
# 0          Semifinals              10
# 1          Semifinals              10
# ...

# %% [markdown]
# End of assignment *Thank you*
