# %%
# 10th July

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Control display of seaborn data - optional
pd.options.display.max_columns = 50
sns.set(style="darkgrid",rc={"axes.facecolor": "CAF1DE"})

# %%
# reading the dataset
df4 = pd.read_csv('bse_dataset4.csv')
df4
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
# confirm data shape
df4.shape
# Out:
# (169, 15)

# %%
# columns
df4.columns
# Out:
# Index(['Timestamp', 'gender', 'Age', 'emotion', 'YOB', 'CGPA',
#        'Do you have a Girl Friend or BOY Friend', 'Do you have Depression?',
#        'Do you have Anxiety?', 'Do you have Panic attack?',
#        'Did you have seek any specialist for a treatment? ', 'Duration',
#        'Pulse', 'Maxpulse', 'Calories'],
#       dtype='object')

# %%
# dropping empty cells
df4_new = df4.dropna()
df4_new
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
# df4 = df4.dropna(inplace=True)
# df4

# %%
# fill empty cells with a value
df4.fillna(100, inplace=True)
df4
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
# calories column
df4['Calories'].fillna(100, inplace=True)

# %%
# print to string
print(df4.to_string())
# Out:
#                Timestamp         gender    Age               emotion            YOB              CGPA Do you have a Girl Friend or BOY Friend Do you have Depression? Do you have Anxiety? Do you have Panic attack? Did you have seek any specialist for a treatment?   Duration  Pulse  Maxpulse  Calories
# 0    05/07/2023 09:38:39           Male   21.0               Content           2002              4.22                                      No                      No                  Yes                       Yes                                                Yes        60    110       130     409.1
# 1    05/07/2023 09:38:57  Marabou stock   45.0                 Weird           2100               8.9                                     Yes                     Yes                  Yes                       Yes                                                 No        60    117       145     479.0
# ...

# %%
# replace using mean, median, mode
# calculate mean
m = df4['Calories'].mean()
# print mean
print(m)
df4['Calories'].fillna(m, inplace=True)
# Out:
# 375.9018292682927

# %%
# print 
print(df4.to_string())
# Out:
#                Timestamp         gender   Age               emotion            YOB              CGPA Do you have a Girl Friend or BOY Friend Do you have Depression? Do you have Anxiety? Do you have Panic attack? Did you have seek any specialist for a treatment?   Duration  Pulse  Maxpulse     Calories
# 0    05/07/2023 09:38:39           Male  21.0               Content           2002              4.22                                      No                      No                  Yes                       Yes                                                Yes        60    110       130   409.100000
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird           2100               8.9                                     Yes                     Yes                  Yes                       Yes                                                 No        60    117       145   479.000000
# ...

# %%
# Set the option to display all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df4

# %%
# empty cells, wrong format, wrong data, duplicate values (Core of data preparation and preprocessing)) 
# calculate median

med = df4['Calories'].median()
print(med)  

df4['Calories'].fillna(med, inplace=True)
# Out:
# 318.6

# %%
# Exercise 1
# calculate mode
mod = df4['Calories'].mode()
print(mod)
# Out:
# 0    300.0
# Name: Calories, dtype: float64

# %%
# wrong format that is hard to analyze (NaN)
# eg 20230112
# NaN row 5 contained NaN values and we filled with 
df4['Timestamp'].fillna('05/07/2023 09:45:13', inplace=True)
df4

# %%
# wrong data
# Row 23,37 contained typo in data 23, 2300 typo, we changed from 2300 to 23
for x in df4.index:
    if df4.loc[x, "gender"] == "Marabou stock":
        df4.drop(x, inplace = True)

df4
# Out:
#                Timestamp   gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39     Male  21.0  Content  2002     4.22
# 2    05/07/2023 09:39:09  Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12     Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14   Female  21.0    Happy  2002     3.63
# 5                    NaN   Female  23.0   Happy   2000      3.8
# ..                   ...      ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09     Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14     male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15     male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35   Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13   Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# 0                                        No                      No
# ...

# %%
# duplicate values
print(df4.duplicated())
# Out:
# 0      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# Length: 168, dtype: bool

# %%
# to drop duplicates
df4.drop_duplicates(inplace=True)

print(df4.duplicated())
# Out:
# 0      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# Length: 167, dtype: bool

# %%
# data visualization using matplotlib 
# (heatmap,pie chart, bar chart, histogram, scatter plot, line graph(dotted,dashed), scatterplot)

# histogram

df4["Age"].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>
